# %% [markdown]
# We will be doing Analysis of minimum 2 dataset

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Data

# %%
#r is used to convert normal string to raw string
data = pd.read_excel(r"C:\Users\DELL\Desktop\Feynn Labs Internship\EV Market Segmentation Data\EV Data\Ev Sales.xlsx")

# %%
data['YEAR'] = pd.to_datetime(data['YEAR']).dt.date

# %%
data.head()
# Out:
#          YEAR  2 W   3 W  4 W  BUS  TOTAL
# 0  2017-04-01   96  4748  198    0   5042
# 1  2017-05-01   91  6720  215    2   7028
# 2  2017-06-01  137  7178  149    1   7465
# 3  2017-07-01  116  8775  120    0   9011
# 4  2017-08-01   99  8905  137    0   9141

# %%
data.tail()
# Out:
#           YEAR     2 W    3 W   4 W  BUS   TOTAL
# 69  2023-01-01   64649  34308  3490   98  102545
# 70  2023-02-01   66033  35995  4850   99  106977
# 71  2023-03-01   86194  45225  8852   89  140360
# 72  2023-04-01   66755  38016  6193   84  111048
# 73  2023-05-01  105154  44615  7736  283  157788

# %% [markdown]
# The Above data has the information of monthly sales of Electric vehicles per category from April 2017 to May 2023.

# %%
data.shape
# Out:
# (74, 6)

# %%
data.size
# Out:
# 444

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    74 non-null     object
#  1   2 W     74 non-null     int64
#  2   3 W     74 non-null     int64
#  3   4 W     74 non-null     int64
#  4   BUS     74 non-null     int64
#  5   TOTAL   74 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 3.6+ KB

# %%
data.describe()
# Out:
#                  2 W           3 W          4 W         BUS          TOTAL
# count      74.000000     74.000000    74.000000   74.000000      74.000000
# mean    16938.729730  14851.351351  1272.567568   82.310811   33144.959459
# std     25846.636971  11002.517635  1841.195763   79.696672   38251.453387
# min        85.000000    668.000000     3.000000    0.000000     958.000000
# 25%      1304.250000   7782.250000   187.750000   11.250000    9147.000000
# 50%      3014.500000  10619.500000   317.500000   74.500000   14526.000000
# 75%     23599.000000  18641.750000  1545.000000  113.500000   43902.750000
# max    105154.000000  45225.000000  8852.000000  331.000000  157788.000000

# %%
#checking null values
data.isnull()
# Out:
#      YEAR    2 W    3 W    4 W    BUS  TOTAL
# 0   False  False  False  False  False  False
# 1   False  False  False  False  False  False
# 2   False  False  False  False  False  False
# 3   False  False  False  False  False  False
# 4   False  False  False  False  False  False
# ..    ...    ...    ...    ...    ...    ...
# 69  False  False  False  False  False  False
# 70  False  False  False  False  False  False
# 71  False  False  False  False  False  False
# 72  False  False  False  False  False  False
# 73  False  False  False  False  False  False
#
# [74 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# YEAR     0
# 2 W      0
# 3 W      0
# 4 W      0
# BUS      0
# TOTAL    0
# dtype: int64

# %% [markdown]
# There are no null values present.

# %%
#checking duplicate values
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Length: 74, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values present.

# %%
data.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11524\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             2 W       3 W       4 W       BUS     TOTAL
# 2 W    1.000000  0.946865  0.957640  0.615954  0.995435
# 3 W    0.946865  1.000000  0.918034  0.627012  0.972932
# 4 W    0.957640  0.918034  1.000000  0.545935  0.960412
# BUS    0.615954  0.627012  0.545935  1.000000  0.624915
# TOTAL  0.995435  0.972932  0.960412  0.624915  1.000000

# %%
# bar plots
plt.figure(figsize=(10,8))
sns.barplot(x= data['YEAR'], y= data['2 W'])
plt.xlabel('Date')
plt.ylabel('Electric 2 Wheeler Sales')
plt.xticks(rotation = 90)
plt.show()

# %%
# bar plots
plt.figure(figsize=(10,8))
sns.barplot(x= data['YEAR'], y= data['3 W'])
plt.xlabel('Date')
plt.ylabel('Electric 3 Wheeler Sales')
plt.xticks(rotation = 90)
plt.show()

# %%
# bar plots
plt.figure(figsize=(10,8))
sns.barplot(x= data['YEAR'], y= data['4 W'])
plt.xlabel('Date')
plt.ylabel('Electric 4 Wheeler Sales')
plt.xticks(rotation = 90)
plt.show()

# %%
# bar plots
plt.figure(figsize=(10,8))
sns.barplot(x= data['YEAR'], y= data['BUS'])
plt.xlabel('Date')
plt.ylabel('Electric Bus Sales')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above four graphs, just from the y-axis scale we can tell the difference (2 W is upto 100000, 3 W upto 40000, 4 W 8000, And bus been upto 300) is preety high.

# %%
plt.figure(figsize=(10,8))
plt.plot('YEAR', '2 W', data=data, label='2W')
plt.plot('YEAR', '3 W', data=data, label='3W')
plt.plot('YEAR', '4 W', data=data, label='4W')
plt.plot('YEAR', 'BUS', data=data, label='BUS')

plt.title('Trends')
plt.xlabel('Years')
plt.ylabel('Electric Vehicle Sales')

plt.legend()

plt.show()

# %% [markdown]
# We can see the differnce in the sales of 2W and 3W other are not even noticible.
#
# So we should focus on producing electric 2 wheeler.

# %% [markdown]
# # Importing 2nd Data

# %%
data2 = pd.read_csv(r"C:\Users\DELL\Desktop\Feynn Labs Internship\EV Market Segmentation Data\EV Data\EV_India.csv")

# %%
data2.head()
# Out:
#    Sr. No.                State Name Total Electric Vehicle  \
# 0        1  Andaman & Nicobar Island                    162
# 1        2             Andra Pradesh                    NaN
# 2        3         Arunachal Pradesh                     20
# 3        4                     Assam                  64766
# 4        5                     Bihar                  83335
#
#   Total Non-Electric Vehicle        Total
# 0                   1,46,945     1,47,107
# 1                        NaN          NaN
# 2                   2,52,965     2,52,985
# 3                  46,77,053    47,41,819
# 4                1,04,07,078  1,04,90,413

# %% [markdown]
# The dataset provides the statewise number of electric vehicles being used on the roads of India as on April 2022.

# %%
data2.shape
# Out:
# (36, 5)

# %%
data2.size
# Out:
# 180

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sr. No.                     36 non-null     int64
#  1   State Name                  36 non-null     object
#  2   Total Electric Vehicle      32 non-null     object
#  3   Total Non-Electric Vehicle  32 non-null     object
#  4   Total                       32 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %% [markdown]
# We have 4 null values.
#
# We need to change the data types of 'Total Electric Vehicle', 'Total Non-Electric Vehicle', 'Total' from object to int.

# %%
data2.describe(include='all')
# Out:
#           Sr. No.                State Name Total Electric Vehicle  \
# count   36.000000                        36                     32
# unique        NaN                        36                     31
# top           NaN  Andaman & Nicobar Island                     21
# freq          NaN                         1                      2
# mean    18.500000                       NaN                    NaN
# std     10.535654                       NaN                    NaN
# min      1.000000                       NaN                    NaN
# 25%      9.750000                       NaN                    NaN
# 50%     18.500000                       NaN                    NaN
# 75%     27.250000                       NaN                    NaN
# max     36.000000                       NaN                    NaN
#
#        Total Non-Electric Vehicle     Total
# count                          32        32
# unique                         32        32
# ...

# %%
data2.isnull().sum()
# Out:
# Sr. No.                       0
# State Name                    0
# Total Electric Vehicle        4
# Total Non-Electric Vehicle    4
# Total                         4
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2.isnull().sum()
# Out:
# Sr. No.                       0
# State Name                    0
# Total Electric Vehicle        0
# Total Non-Electric Vehicle    0
# Total                         0
# dtype: int64

# %%
data2['Total Electric Vehicle'] = data2['Total Electric Vehicle'].str.replace(',','').astype(int)
data2['Total Non-Electric Vehicle'] = data2['Total Non-Electric Vehicle'].str.replace(',','').astype(int)
data2['Total'] = data2['Total'].str.replace(',','').astype(int)

# %%
data2.head()
# Out:
#    Sr. No.                State Name  Total Electric Vehicle  \
# 0        1  Andaman & Nicobar Island                     162
# 2        3         Arunachal Pradesh                      20
# 3        4                     Assam                   64766
# 4        5                     Bihar                   83335
# 5        6                Chandigarh                    2812
#
#    Total Non-Electric Vehicle     Total
# 0                      146945    147107
# 2                      252965    252985
# 3                     4677053   4741819
# 4                    10407078  10490413
# 5                      746881    749693

# %%
data2.describe()
# Out:
#          Sr. No.  Total Electric Vehicle  Total Non-Electric Vehicle  \
# count  32.000000               32.000000                3.200000e+01
# mean   18.625000            41699.531250                8.692801e+06
# std    10.557828            68261.115171                1.079020e+07
# min     1.000000               20.000000                3.830200e+04
# 25%     9.750000              485.250000                4.892432e+05
# 50%    18.500000            15807.500000                3.994547e+06
# 75%    27.250000            52766.750000                1.288081e+07
# max    36.000000           337180.000000                4.009249e+07
#
#               Total
# count  3.200000e+01
# mean   8.734500e+06
# std    1.084501e+07
# min    3.832800e+04
# 25%    4.896950e+05
# 50%    4.042434e+06
# 75%    1.290410e+07
# max    4.042967e+07

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values.

# %%
data2.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11524\1981098430.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2.corr()
#                              Sr. No.  Total Electric Vehicle  \
# Sr. No.                     1.000000                0.168410
# Total Electric Vehicle      0.168410                1.000000
# Total Non-Electric Vehicle  0.238946                0.801914
# Total                       0.238798                0.804154
#
#                             Total Non-Electric Vehicle     Total
# Sr. No.                                       0.238946  0.238798
# Total Electric Vehicle                        0.801914  0.804154
# Total Non-Electric Vehicle                    1.000000  0.999993
# Total                                         0.999993  1.000000

# %%
#print(plt.colormaps())      For colour palatte names

# %%
# Generate a color palette with a large number of colors
cmap = plt.get_cmap('Wistia', len(data2))  # 'tab20c' supports a large number of colors
colors = [cmap(i) for i in range(len(data2))]


plt.pie(x= 'Total Electric Vehicle',
        labels= 'State Name',
        autopct='%2.2f%%',
        data = data2.sort_values('Total Electric Vehicle'),
        wedgeprops = {'width':0.6}, startangle=90,
        colors=colors)

# Adding a title
plt.title('State wise Electric Vehicle Pie Chart')

# Displaying the plot
plt.show()

# %%
sorted_indices = np.argsort(data2['Total Electric Vehicle'])[::-1] #reverse order for descending

plt.bar(data2['State Name'].iloc[sorted_indices], data2['Total Electric Vehicle'].iloc[sorted_indices],color = 'orange')
plt.xlabel('State Name')
plt.ylabel('Total Number of Vehicle')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Uttar Pradesh has the highest number of electric vehicles a woophing 25% out of total.
#
# If we want to target the states for electric vehicles we can set UP, Delhi, Karnataka, Maharashtra as our target states.

# %%
# Generate a color palette with a large number of colors
cmap = plt.get_cmap('crest', len(data2))  # 'tab20c' supports a large number of colors
colors = [cmap(i) for i in range(len(data2))]

plt.pie(x= 'Total Non-Electric Vehicle',
        labels= 'State Name',
        autopct='%2.2f%%',
        data = data2.sort_values('Total Non-Electric Vehicle'),
        wedgeprops = {'width':0.6}, startangle=90,
        colors=colors)

# Adding a title
plt.title('State wise Non-Electric Vehicle Pie Chart')

# Displaying the plot
plt.show()

# %%
df_sorted = data2.sort_values(by='Total Non-Electric Vehicle', ascending=False)

plt.bar(df_sorted['State Name'],df_sorted['Total Non-Electric Vehicle'],color = 'navy')
plt.xlabel('State Name')
plt.ylabel('Total Number of Vehicle')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The on road non-electric vehicles are high in the states of Uttar Pradesh, Maharashtra, Tamil Nadu, and Karnataka.

# %%
# Generate a color palette with a large number of colors
cmap = plt.get_cmap('twilight_shifted', len(data2))  # 'tab20c' supports a large number of colors
colors = [cmap(i) for i in range(len(data2))]

plt.pie(x= 'Total',
        labels= 'State Name',
        autopct='%2.2f%%',
        data = data2.sort_values('Total'),
        wedgeprops = {'width':0.6}, startangle=90,
        colors=colors)

# Adding a title
plt.title('State wise Total Pie Chart')

# Displaying the plot
plt.show()

# %%
sorted_indices = np.argsort(data2['Total'])[::-1] #reverse order for descending

plt.bar(data2['State Name'].iloc[sorted_indices], data2['Total'].iloc[sorted_indices],color = 'purple')
plt.xlabel('State Name')
plt.ylabel('Total Number of Vehicle')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The Total number of on road vehicles are highest in the states of Uttar Pradesh, Maharashtra, Tamil Nadu, Karnataka.

# %% [markdown]
# From The above insights it will be more profitable to sale our electic vehicles in the states of Uttar Pradesh, Maharashtra, Tamil Nadu, Karnataka.
#
# Maharashtra and Uttar Pradesh both states have high number of both Electric and non-electric vehicles on road.
#
# And due to the indian government moving towards clean energy we have large scope of in these states during these transition phase.

# %% [markdown]
# # Importing Dataset 3

# %%
data3 = pd.read_csv('C:/Users/DELL/Desktop/Feynn Labs Internship/EV Market Segmentation Data/EV Data/EV Maker by Place.csv')

# %% [markdown]
# List of popular EV Makers and their location of Manufacturing Plant

# %%
data3.head()
# Out:
#             EV Maker        Place        State
# 0        Tata Motors         Pune  Maharashtra
# 1  Mahindra Electric    Bengaluru    Karnataka
# 2       Ather Energy    Bengaluru    Karnataka
# 3      Hero Electric    New Delhi        Delhi
# 4       Ola Electric  Krishnagiri   Tamil Nadu

# %%
data3.shape
# Out:
# (62, 3)

# %%
data3.size
# Out:
# 186

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EV Maker  62 non-null     object
#  1   Place     62 non-null     object
#  2   State     62 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
data3.describe()
# Out:
#                      EV Maker Place        State
# count                      62    62           62
# unique                     61    36           13
# top     Lohia Auto Industries  Pune  Maharashtra
# freq                        2     7           15

# %%
data3.isnull().sum()
# Out:
# EV Maker    0
# Place       0
# State       0
# dtype: int64

# %%
data3.duplicated().sum()
# Out:
# 1

# %%
data3[data3.duplicated()]
# Out:
#                  EV Maker     Place        State
# 60  Lohia Auto Industries  Kashipur  Uttarakhand

# %%
data3.drop_duplicates(inplace=True)

# %%
data3.duplicated().sum()
# Out:
# 0

# %%
data3.columns
# Out:
# Index(['EV Maker', 'Place', 'State'], dtype='object')

# %%
for i in data3.columns:
    print('Unique Values of column', i)
    print('')
    print(data3[i].unique())
    print('')
# Out:
# Unique Values of column EV Maker
#
# ['Tata Motors' 'Mahindra Electric' 'Ather Energy' 'Hero Electric'
#  'Ola Electric' 'Ashok Leyland' 'TVS Motor Company' 'Bajaj Auto'
#  'MG Motor India' 'Hyundai Motor India' 'Revolt Motors' 'Ampere Vehicles'
#  'Okinawa Autotech' 'Kinetic Green Energy' 'BYD India' 'JBM Auto'
#  'Piaggio Vehicles' 'Hero MotoCorp' 'Etrio Automobiles' 'Triton Electric'
#  'Simple Energy' 'Minda Industries' 'Exide Industries' 'Greaves Cotton'
#  'Maruti Suzuki India' 'Renault India' 'Citroën India' 'Audi India'
#  'Mercedes-Benz India' 'Kia Motors India' 'Volvo Eicher' 'JSW Energy'
#  'Olectra Greentech' 'Force Motors' 'TVS Electronics' 'Royal Enfield'
#  'Bharat Forge' 'Hindustan Motors' 'Atul Auto' 'SML Isuzu' 'Mahindra Reva'
#  'Ajanta Manufacturing' 'Tata Power' 'Ashok Leyland (EV Bus)'
#  'HOP Electric Mobility' 'Omega Seiki Mobility' 'Bajaj Auto (EV)'
#  'Tata AutoComp Systems' 'Bosch India' 'Lohia Auto Industries'
# ...

# %%
data3['State'].value_counts()
# Out:
# Maharashtra       15
# Tamil Nadu        11
# Karnataka          6
# Haryana            6
# Gujarat            5
# Delhi              4
# Rajasthan          4
# Telangana          3
# West Bengal        3
# Andhra Pradesh     1
# Madhya Pradesh     1
# Punjab             1
# Uttarakhand        1
# Name: State, dtype: int64

# %%
sns.countplot(data=data3,y='State', palette='viridis' )
# Out:
# <AxesSubplot: xlabel='count', ylabel='State'>

# %%
# Generate a color palette with a large number of colors
cmap = plt.get_cmap('twilight_shifted', len(data3))  # 'tab20c' supports a large number of colors
colors = [cmap(i) for i in range(len(data3))]

plt.figure(figsize=(8,6))
plt.pie(x= data3['State'].value_counts(),
        labels= data3['State'].unique(),
        autopct='%2.2f%%',
        data= data3,
        wedgeprops = {'width':0.6}, startangle=270,
        colors=colors)

# Adding a title
plt.title('State wise Production Pie Chart')

# Displaying the plot
plt.show()

# %% [markdown]
# Considering the above diagram Maharashtra is the best State for the Production of EV.
#
# We can target 2 States for production Maharashta and Karnataka.

# %%
data3['Place'].value_counts()
# Out:
# Pune             7
# Bengaluru        6
# Chennai          5
# New Delhi        3
# Mumbai           3
# Hyderabad        3
# Bhiwadi          2
# Kolkata          2
# Faridabad        2
# Coimbatore       2
# Akurdi           1
# Pithampur        1
# Jaipur           1
# Alwar            1
# Kashipur         1
# Morbi            1
# Gurugram         1
# Ahmednagar       1
# Delhi            1
# Ropar            1
# Rajkot           1
# Uttarpara        1
# Manesar          1
# Anantapur        1
# Chakan           1
# Aurangabad       1
# Thiruvallur      1
# Bhuj             1
# Dharuhera        1
# Baramati         1
# Sriperumbudur    1
# Gurgaon          1
# Halol            1
# Hosur            1
# Krishnagiri      1
# Ahmedabad        1
# Name: Place, dtype: int64

# %%
sns.countplot(data=data3,y='Place', palette='viridis' )
# Out:
# <AxesSubplot: xlabel='count', ylabel='Place'>

# %%
# Generate a color palette with a large number of colors
cmap = plt.get_cmap('twilight_shifted', len(data3))  # 'tab20c' supports a large number of colors
colors = [cmap(i) for i in range(len(data3))]

plt.figure(figsize=(8,6))
plt.pie(x= data3['Place'].value_counts(),
        labels= data3['Place'].unique(),
        autopct='%2.2f%%',
        data= data3,
        wedgeprops = {'width':0.6}, startangle=270,
        colors=colors)

# Adding a title
plt.title('Place wise Production Pie Chart')

# Displaying the plot
plt.show()

# %% [markdown]
# From the above pie chart we can get two places which are good for production according to the data of various company production locations. Pune and Bengluru. Both are from the states we discussed in the previous diagram.

# %% [markdown]
# # Importing Dataset 4

# %%
data4 = pd.read_csv(r'C:\Users\DELL\Desktop\Feynn Labs Internship\EV Market Segmentation Data\EV Data\ev-2w-data.csv')

# %%
data4.head()
# Out:
#    id                  Model      Manufacturer Vehicle Type  \
# 0   1          Aura 300 Plus      Ather Energy      Scooter
# 1   2      Pure EV Epluto 7G           Pure EV      Scooter
# 2   3  Bajaj Chetak Electric        Bajaj Auto      Scooter
# 3   4    Okinawa iPraise Pro  Okinawa Autotech      Scooter
# 4   5  Hero Electric Opto EV     Hero Motocorp      Scooter
#
#    Battery Capacity (kWh)  Range per Charge (km)  Charging Time     Price  \
# 0                     2.9                    116            4.5  129000.0
# 1                     2.7                    120            3.0  109000.0
# 2                     4.0                     95            5.0  150000.0
# 3                     2.5                    100            3.0   85000.0
# 4                     2.2                     75            3.0   75000.0
#
#    Power (HP or kW)  Top Speed (km/h)  Year of Manufacture
# 0               6.0              80.0               2021.0
# ...

# %% [markdown]
# This is electric 2 Wheeler data for analysis

# %%
data4.shape
# Out:
# (50, 11)

# %%
data4.size
# Out:
# 550

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      50 non-null     int64
#  1   Model                   50 non-null     object
#  2   Manufacturer            50 non-null     object
#  3   Vehicle Type            50 non-null     object
#  4   Battery Capacity (kWh)  50 non-null     float64
#  5   Range per Charge (km)   50 non-null     int64
#  6   Charging Time           49 non-null     float64
#  7   Price                   49 non-null     float64
#  8   Power (HP or kW)        49 non-null     float64
#  9   Top Speed (km/h)        49 non-null     float64
#  10  Year of Manufacture     49 non-null     float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.4+ KB

# %%
data4.describe()
# Out:
#              id  Battery Capacity (kWh)  Range per Charge (km)  Charging Time  \
# count  50.00000               50.000000              50.000000      49.000000
# mean   25.50000                3.188000             120.160000       3.755102
# std    14.57738                0.950325              30.370743       0.947158
# min     1.00000                2.200000              75.000000       2.500000
# 25%    13.25000                2.550000             100.000000       3.000000
# 50%    25.50000                2.900000             118.000000       3.500000
# 75%    37.75000                3.500000             140.000000       4.500000
# max    50.00000                6.200000             200.000000       6.000000
#
#                Price  Power (HP or kW)  Top Speed (km/h)  Year of Manufacture
# count      49.000000         49.000000         49.000000            49.000000
# mean   120469.387755          6.795918         73.775510          2021.204082
# ...

# %%
data4.isnull().sum()
# Out:
# id                        0
# Model                     0
# Manufacturer              0
# Vehicle Type              0
# Battery Capacity (kWh)    0
# Range per Charge (km)     0
# Charging Time             1
# Price                     1
# Power (HP or kW)          1
# Top Speed (km/h)          1
# Year of Manufacture       1
# dtype: int64

# %%
data4.dropna(inplace=True)

# %%
data4.isnull().sum()
# Out:
# id                        0
# Model                     0
# Manufacturer              0
# Vehicle Type              0
# Battery Capacity (kWh)    0
# Range per Charge (km)     0
# Charging Time             0
# Price                     0
# Power (HP or kW)          0
# Top Speed (km/h)          0
# Year of Manufacture       0
# dtype: int64

# %%
data4.shape
# Out:
# (49, 11)

# %%
data4.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11524\4151777525.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data4.corr()
#                               id  Battery Capacity (kWh)  \
# id                      1.000000               -0.024779
# Battery Capacity (kWh) -0.024779                1.000000
# Range per Charge (km)   0.056306                0.848366
# Charging Time          -0.081587                0.734558
# Price                  -0.182420                0.883887
# Power (HP or kW)       -0.201503                0.678813
# Top Speed (km/h)        0.046630                0.699437
# Year of Manufacture     0.762389                0.055863
#
#                         Range per Charge (km)  Charging Time     Price  \
# id                                   0.056306      -0.081587 -0.182420
# ...

# %%
sns.heatmap(data4.corr(), annot=True, linecolor='White', linewidths=0.2, fmt='.2g')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11524\3367940666.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data4.corr(), annot=True, linecolor='White', linewidths=0.2, fmt='.2g')
# <AxesSubplot: >

# %%
sns.pairplot(data4)

# %%
data4.columns
# Out:
# Index(['id', 'Model', 'Manufacturer', 'Vehicle Type', 'Battery Capacity (kWh)',
#        'Range per Charge (km)', 'Charging Time', 'Price', 'Power (HP or kW)',
#        'Top Speed (km/h)', 'Year of Manufacture'],
#       dtype='object')

# %%
sns.countplot(x='Vehicle Type', data=data4)
# Out:
# <AxesSubplot: xlabel='Vehicle Type', ylabel='count'>

# %% [markdown]
# Electric Scooters are more popular than electric bike

# %%
sns.countplot(x='Battery Capacity (kWh)', data=data4 ,palette='rocket')
# Out:
# <AxesSubplot: xlabel='Battery Capacity (kWh)', ylabel='count'>

# %% [markdown]
# The Battery Capacity ranges from 2.2(kWh) to 6.2(KWh).
#
# But it rarely goes up after 4.5.
#
# Meaning the ideal ranges should be from 2.5 to 4.0.

# %%
sns.countplot(x=data4['Range per Charge (km)'])
# Out:
# <AxesSubplot: xlabel='Range per Charge (km)', ylabel='count'>

# %% [markdown]
# There are more electric 2 Wheelers with the range of 100 to 120 km per charge.

# %%
sns.barplot(data=data4, x='Battery Capacity (kWh)', y='Range per Charge (km)', palette='rocket_r')
# Out:
# <AxesSubplot: xlabel='Battery Capacity (kWh)', ylabel='Range per Charge (km)'>

# %% [markdown]
# The range will obivioulsy depend on the battery capacity. More the capacity, more will be the range.
#
# The Ideal battery capacity of 2.9 to 4.5 will cover the range of 120 to 150 KM.

# %%
sns.histplot(data=data4, x = 'Charging Time', kde=True)
# Out:
# <AxesSubplot: xlabel='Charging Time', ylabel='Count'>

# %% [markdown]
# On averge the Charging time lies between 3 to 3.5 Hours.

# %%
sns.scatterplot(data= data4, x= 'Battery Capacity (kWh)', y='Charging Time')
# Out:
# <AxesSubplot: xlabel='Battery Capacity (kWh)', ylabel='Charging Time'>

# %%
sns.scatterplot(data= data4, x= 'Range per Charge (km)', y='Charging Time')
# Out:
# <AxesSubplot: xlabel='Range per Charge (km)', ylabel='Charging Time'>

# %%
sns.scatterplot(data=data4, x='Battery Capacity (kWh)', y='Range per Charge (km)', hue='Charging Time')
# Out:
# <AxesSubplot: xlabel='Battery Capacity (kWh)', ylabel='Range per Charge (km)'>

# %%
data4.columns
# Out:
# Index(['id', 'Model', 'Manufacturer', 'Vehicle Type', 'Battery Capacity (kWh)',
#        'Range per Charge (km)', 'Charging Time', 'Price', 'Power (HP or kW)',
#        'Top Speed (km/h)', 'Year of Manufacture'],
#       dtype='object')

# %%
data4['Power (HP or kW)'].value_counts()
# Out:
# 3.0     15
# 5.0     10
# 4.0      7
# 6.0      6
# 25.0     3
# 20.0     3
# 2.0      2
# 7.0      2
# 21.0     1
# Name: Power (HP or kW), dtype: int64

# %%
sns.countplot(data=data4, x= 'Power (HP or kW)', palette='seismic')
# Out:
# <AxesSubplot: xlabel='Power (HP or kW)', ylabel='count'>

# %% [markdown]
# Power is between 3.0 to 5.0 HP or kW.

# %%
sns.countplot(data=data4, x= 'Top Speed (km/h)', palette='seismic')
# Out:
# <AxesSubplot: xlabel='Top Speed (km/h)', ylabel='count'>

# %% [markdown]
# The top speed is either 60 or 80 Km/h (mostly).

# %%
sns.barplot(data=data4, x='Power (HP or kW)', y='Top Speed (km/h)', palette='rocket_r')
# Out:
# <AxesSubplot: xlabel='Power (HP or kW)', ylabel='Top Speed (km/h)'>

# %%
sns.barplot(data=data4, x='Range per Charge (km)', y='Top Speed (km/h)', palette='rocket_r')
# Out:
# <AxesSubplot: xlabel='Range per Charge (km)', ylabel='Top Speed (km/h)'>

# %% [markdown]
# As the range increases top speed also increases.

# %%
sns.boxplot(data4['Price'])
# Out:
# <AxesSubplot: >

# %%
data4[data4['Price'] > 175000]
# Out:
#     id     Model Manufacturer Vehicle Type  Battery Capacity (kWh)  \
# 5    6  Tork T6X  Tork Motors         Bike                     6.2
# 12  13  Tork T6X  Tork Motors         Bike                     6.2
# 18  19  Tork T6X  Tork Motors         Bike                     6.2
#
#     Range per Charge (km)  Charging Time     Price  Power (HP or kW)  \
# 5                     200            5.0  250000.0              25.0
# 12                    200            5.0  250000.0              25.0
# 18                    200            5.0  250000.0              25.0
#
#     Top Speed (km/h)  Year of Manufacture
# 5              100.0               2021.0
# 12             100.0               2021.0
# 18             100.0               2021.0

# %% [markdown]
# Price lies between 70000 to 170000. With the median of 120000.

# %%
sns.barplot(data= data4, y=data4['Price'], x=data4['Power (HP or kW)'])
# Out:
# <AxesSubplot: xlabel='Power (HP or kW)', ylabel='Price'>

# %%
sns.barplot(data= data4, x=data4['Year of Manufacture'], y=data4['Battery Capacity (kWh)'])
# Out:
# <AxesSubplot: xlabel='Year of Manufacture', ylabel='Battery Capacity (kWh)'>

# %%
sns.barplot(data= data4, x=data4['Year of Manufacture'], y=data4['Range per Charge (km)'])
# Out:
# <AxesSubplot: xlabel='Year of Manufacture', ylabel='Range per Charge (km)'>

# %% [markdown]
# # Model Building

# %%
df = data4.copy()

# %%
col = ['id','Model','Manufacturer','Vehicle Type']
df.drop(col, axis=1, inplace=True)

# %%
from sklearn.cluster import KMeans
# Perform k-means clustering with k values from 2 to 7
k_values = range(2, 11)
inertia_values = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=1234)
    kmeans.fit(df)
    inertia_values.append(kmeans.inertia_)

# Plotting the Elbow Method
plt.bar(k_values, inertia_values, color='#063e6b', alpha=0.7)
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Segments (k)')
plt.ylabel('Sum of within cluster distances')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# plotting the results of Elbow

wcss = []

for i in range(1, 11):
    kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
    kmean.fit(df)
    wcss.append(kmean.inertia_)

plt.figure(figsize=(8,6))
plt.title('Plot of the Elbow Method', size=15, family='serif')
plt.plot(range(1, 11), wcss)
plt.xticks(range(1, 11), family='serif')
plt.yticks(family='serif')
plt.xlabel('Number of Custers (K)', family='serif')
plt.ylabel('WCSS', family='serif')
plt.grid()
plt.tick_params(axis='both', direction='inout', length=6, color='purple', grid_color='lightgray', grid_linestyle='--')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
# ...

# %%
from sklearn.metrics import adjusted_rand_score

# Performing k-Means clustering for k values ranging from 2 to 4
results = {}
for k in range(2, 5):
    kmeans_model = KMeans(n_clusters=k, n_init='auto', random_state=1234)
    model = kmeans_model.fit(df)
    kmeans_labels = model.labels_
    results[str(k)] = kmeans_labels
    df['Cluster Number'] = kmeans_labels

# Calculating adjusted rand index for each k value
ari_values = []
for k1 in range(2, 5):
    ari_values.append([adjusted_rand_score(results[str(k1)], results[str(k2)]) for k2 in range(2, 5)])

# Convert ari_values to a NumPy array for easier plotting
ari_values = np.array(ari_values)

# Create a box plot
plt.boxplot(ari_values.T, labels=list(range(2, 5)))
plt.xlabel('Number of Segments (k)')
plt.ylabel('Adjusted Rand Index')
plt.title('Global stability of k-means segmentation solutions')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmean = KMeans(n_clusters=4, init='k-means++', random_state=90)
kmean.fit(df)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=90)

# %%
# check the labels assigned to each data point
print(kmean.labels_)
# Out:
# [3 3 0 1 1 2 0 0 0 3 1 1 2 0 0 3 1 1 2 0 1 1 1 0 3 1 0 0 3 1 1 1 0 1 0 3 1
#  0 0 3 1 1 1 0 3 0 3 1 1]

# %%
y_kmeans = kmean.predict(df)

# Plot the data points and color them by their cluster label
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=y_kmeans, s=50, cmap='viridis')

# Plot the cluster centers
centers = kmean.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='*')

plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
